# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['figure.figsize']=(9,6)
plt.rcParams['figure.dpi']=80
# %matplotlib inline

# %%
df=pd.read_csv("/content/drive/MyDrive/iris-1.csv")

# %%
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
plt.hist(df['Sepal.Length'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Petal.Length'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data=df['Sepal.Length'] ,kde=True)
# Out:
# <Axes: xlabel='Sepal.Length', ylabel='Count'>

# %%
plt.pie(df['Sepal.Length'])
# Out:
# ([<matplotlib.patches.Wedge at 0x792fb5811cf0>,
# ...
#  [Text(1.0998162248289156, 0.020106506486022895, ''),
#   Text(1.0983893303845753, 0.059505284616782936, ''),
#   Text(1.0956920682406373, 0.0972568331509659, ''),
#   Text(1.091842090596001, 0.1337192925607762, ''),
#   Text(1.0865955946241563, 0.17120167564418406, ''),
#   Text(1.0794604973247504, 0.21157749104146875, ''),
#   Text(1.0711853524326178, 0.25012385078958144, ''),
#   Text(1.061946535861541, 0.2868266984987159, ''),
#   Text(1.051681945368862, 0.322436173195822, ''),
#   Text(1.0403517900227819, 0.35730680513585744, ''),
#   Text(1.0264549462634536, 0.39546206302411735, ''),
#   Text(1.0113144459682202, 0.4327159476792971, ''),
#   Text(0.9958295372217366, 0.4672510383046166, ''),
#   Text(0.9800624176136543, 0.4994773844542706, ''),
#   Text(0.9613427184591771, 0.5346215274991455, ''),
#   Text(0.9384959352390051, 0.5737816479636355, ''),
#   Text(0.9149313166628202, 0.6106559471499793, ''),
# ...

# %%
 plt.pie(df['Sepal.Length'].value_counts(), labels=['B','A'], autopct='%.0f%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-db1e698dff2b> in <cell line: 1>()
# ----> 1 plt.pie(df['Sepal.Length'].value_counts(), labels=['B','A'], autopct='%.0f%%')
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
plt.plot([1,2,5,4])
plt.show()

# %%
plt.stairs(df['Sepal.Length'], linewidth=2)

# %%
plt.plot(df['Petal.Length'], linestyle = '--')
plt.show()

# %%
plt.scatter(df['Petal.Length'], df['Sepal.Length'])

# %%
df[['Sepal.Length','Petal.Length']].corr()
# Out:
#               Sepal.Length  Petal.Length
# Sepal.Length      1.000000      0.871754
# Petal.Length      0.871754      1.000000

# %%
plt.scatter(df['Sepal.Length'],df['Petal.Length'])
plt.scatter(df['Petal.Width'],df['Sepal.Width'])

# %%
plt.boxplot(df['Sepal.Length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x792fb568f610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x792fb5796740>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x792fb568edd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x792fb5796c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x792fb5797cd0>],
#  'means': []}

# %%
sns.boxplot(['Sepal.Length'])
# Out:
# <Axes: >

# %%
sns.boxplot(['Sepal.Length'])
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
df['Sepal.Length'].mean()
# Out:
# 5.843333333333334

# %%
df['Sepal.Width'].mean()
# Out:
# 3.0573333333333337

# %%
df['Petal.Length'].mean()
# Out:
# 3.7580000000000005

# %%
df1=df['Sepal.Length']

# %%
df1.median()
# Out:
# 5.8

# %%
df1.mode()
# Out:
# 0    5.0
# Name: Sepal.Length, dtype: float64

# %%
df1.std()
# Out:
# 0.828066127977863

# %%
df2=df['Sepal.Width']

# %%
df2.mean()
# Out:
# 3.0573333333333337

# %%
df2.median()
# Out:
# 3.0

# %%
df2.mode()
# Out:
# 0    3.0
# Name: Sepal.Width, dtype: float64

# %%
df2.std()
# Out:
# 0.4358662849366982

# %%
df3=df['Petal.Length']

# %%
df3.mean()
# Out:
# 3.7580000000000005

# %%
df3.mode()
# Out:
# 0    1.4
# 1    1.5
# Name: Petal.Length, dtype: float64

# %%
df3.median()
# Out:
# 4.35

# %%
df3.std()
# Out:
# 1.7652982332594662

# %%
df[df1>6]
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 50           51           7.0          3.2           4.7          1.4
# 51           52           6.4          3.2           4.5          1.5
# 52           53           6.9          3.1           4.9          1.5
# 54           55           6.5          2.8           4.6          1.5
# 56           57           6.3          3.3           4.7          1.6
# ..          ...           ...          ...           ...          ...
# 144         145           6.7          3.3           5.7          2.5
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
#
#         Species
# 50   versicolor
# 51   versicolor
# 52   versicolor
# 54   versicolor
# 56   versicolor
# ..          ...
# ...

# %%
([df1>6],[df3>5.3])
# Out:
# ([0      False
#   1      False
#   2      False
#   3      False
#   4      False
#          ...
#   145     True
#   146     True
#   147     True
#   148     True
#   149    False
#   Name: Sepal.Length, Length: 150, dtype: bool],
#  [0      False
#   1      False
#   2      False
#   3      False
#   4      False
#          ...
#   145    False
#   146    False
#   147    False
#   148     True
#   149    False
#   Name: Petal.Length, Length: 150, dtype: bool])

# %%
df[df3>6]
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 105         106           7.6          3.0           6.6          2.1
# 107         108           7.3          2.9           6.3          1.8
# 109         110           7.2          3.6           6.1          2.5
# 117         118           7.7          3.8           6.7          2.2
# 118         119           7.7          2.6           6.9          2.3
# 122         123           7.7          2.8           6.7          2.0
# 130         131           7.4          2.8           6.1          1.9
# 131         132           7.9          3.8           6.4          2.0
# 135         136           7.7          3.0           6.1          2.3
#
#        Species
# 105  virginica
# 107  virginica
# 109  virginica
# 117  virginica
# 118  virginica
# 122  virginica
# 130  virginica
# 131  virginica
# 135  virginica
